# %%
# Thoomas Goldman 2023
# DOLPHINN
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle 

#Get the absolute path of the current scriptf
current_path = os.path.dirname(os.path.abspath('__file__'))
dolphinn_path = os.path.join(current_path, '..')
sys.path.append(dolphinn_path)

from DOLPHINN.pinn import DOLPHINN 
from DOLPHINN.training import Scheduler, Restarter, Restorer
from DOLPHINN.metrics import FinalDr, FinalDv, FinalDm, Fuel, FuelTUDAT, FinalRadius
from DOLPHINN.callbacks import StoreAnimationData

from DOLPHINN import plotting
from DOLPHINN import utils
# Out:
# Using backend: tensorflow
# Other supported backends: tensorflow.compat.v1, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
mu = 1.32712440042e20 # SUN
m = 100 #Spacecraft mass
AU = 1.5e11 #EARTH-SUN
a = 10
umax = 0.1
isp = 2500

rp = AU
ra = 1.5*AU

e = (ra - rp)/(ra + rp)
sma = (rp + ra)/2

# Initial state
r0 = AU
theta0 = 0
vr0 = 0
vt0 = np.sqrt(mu/r0)
initial_state = np.array([r0, theta0, vr0, vt0])

# Final state
rfinal = 1.5*AU
theta_final = 6*np.pi
vr_final = 0
vt_final = np.sqrt(mu/rfinal)
final_state = np.array([rfinal, theta_final, vr_final, vt_final])

# Non dimensionalize
length_scale = AU
time_scale = AU / vt0

initial_state[:1] = initial_state[:1]/length_scale
initial_state[2:] = initial_state[2:]*time_scale/length_scale

final_state[:1] = final_state[:1]/length_scale
final_state[2:] = final_state[2:]*time_scale/length_scale

# Integration times
period = 2*np.pi*np.sqrt(sma**3/mu)
t0 = 0
tfinal = 3*period
#tfinal = 3.2*time_scale
N = 200

# Network architecture
input_dimension = 1
output_dimension = 7
neurons = 5
hidden_layers = 3

#layer_size = [input_dimension] + [[neurons]*output_dimension] * hidden_layers + [output_dimension] # Parralel networks
layer_size = [input_dimension] + [20]*4 + [output_dimension] # 

data = {"initial_state": initial_state,
        "final_state": final_state,
        "mu": mu,
        "m": m,
        "a": a,
        "umax": umax,
        "isp": isp,
        "length_scale": length_scale,
        "time_scale": time_scale,
        "t0": t0/time_scale,
        "tfinal": tfinal/time_scale,
        "architecture": layer_size,
        "activation": "tanh",
        "N_train": N,
        "N_boundary": 2,
        "N_test": N,
        "sampler": "perturbed_uniform_tf"}

# %%
base_folder = "../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/"
weigths = np.geomspace(1e-9, 1e-5, 5)

for i, weigth in enumerate(weigths):
    for j in range(5): 
        
        print(f"[DOLPHINN] Weight: {weigth} ({i}/{len(weigths)}) ({j}/5)")

        problem = DOLPHINN(data,
                            "TwoBodyProblemRadialThetaNonDimensionalControl_mass",
                            output_transform = "InitialFinalStateLayer_RadialTheta_tanh_mass",
                            objective = "OptimalFuel", 
                            metrics = [FinalDr, FinalDv, FinalDm, Fuel], 
                            verbose= False)

        restarter = Restarter([(1e-2, 3000)], loss_weigths = [1, 1, 1, 1, 1e-5, weigth])
        schedule = Scheduler([(1e-3, 5000), (1e-4, 10000), (5e-3, 4000), (1e-4, 5000), (5e-3, 4000), (1e-4, 5000)],
                             loss_weigths= [1, 1, 1, 1, 1e-5, weigth]
                            )

        problem.train([restarter, schedule])
        problem.store(base_folder + f"weight_{i}_#{j}/")
# Out:
# [DOLPHINN] Weight: 1e-09 (0/5) (0/5)
# 'compile' took 0.001930 s
#
# Training model...
#
# 'train' took 11.411962 s
#
# 'compile' took 0.084720 s
#
# Training model...
#
# 'train' took 12.838339 s
#
# 'compile' took 0.070693 s
#
# Training model...
#
# 'train' took 19.809538 s
#
# 'compile' took 0.069334 s
#
# Training model...
#
# 'train' took 11.038587 s
#
# 'compile' took 0.066137 s
#
# Training model...
#
# 'train' took 12.484781 s
#
# 'compile' took 0.067009 s
#
# Training model...
#
# 'train' took 11.414578 s
#
# 'compile' took 0.070532 s
#
# Training model...
#
# 'train' took 12.493301 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#0/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#0/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#0/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#0/config
# [DOLPHINN] Weight: 1e-09 (0/5) (1/5)
# 'compile' took 0.002096 s
#
# Training model...
#
# 'train' took 11.597575 s
#
# 'compile' took 0.082837 s
#
# Training model...
#
# 'train' took 12.917430 s
#
# 'compile' took 0.070159 s
#
# Training model...
#
# 'train' took 20.066413 s
#
# 'compile' took 0.067131 s
#
# Training model...
#
# 'train' took 11.608005 s
#
# 'compile' took 0.068165 s
#
# Training model...
#
# 'train' took 12.569139 s
#
# 'compile' took 0.068934 s
#
# Training model...
#
# 'train' took 11.215794 s
#
# 'compile' took 0.065801 s
#
# Training model...
#
# 'train' took 12.517070 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#1/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#1/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#1/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#1/config
# [DOLPHINN] Weight: 1e-09 (0/5) (2/5)
# 'compile' took 0.001113 s
#
# Training model...
#
# 'train' took 11.347869 s
#
# 'compile' took 0.001395 s
#
# Training model...
#
# 'train' took 12.117096 s
#
# 'compile' took 0.087298 s
#
# Training model...
#
# 'train' took 13.366186 s
#
# 'compile' took 0.067865 s
#
# Training model...
#
# 'train' took 21.795096 s
#
# 'compile' took 0.066534 s
#
# Training model...
#
# 'train' took 11.750867 s
#
# 'compile' took 0.065646 s
#
# Training model...
#
# 'train' took 17.519508 s
#
# 'compile' took 0.072628 s
#
# Training model...
#
# 'train' took 14.734309 s
#
# 'compile' took 0.070391 s
#
# Training model...
#
# 'train' took 17.306803 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#2/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#2/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#2/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#2/config
# [DOLPHINN] Weight: 1e-09 (0/5) (3/5)
# 'compile' took 0.001438 s
#
# Training model...
#
# 'train' took 15.077662 s
#
# 'compile' took 0.093061 s
#
# Training model...
#
# 'train' took 16.601136 s
#
# 'compile' took 0.089146 s
#
# Training model...
#
# 'train' took 26.490008 s
#
# 'compile' took 0.071613 s
#
# Training model...
#
# 'train' took 14.420358 s
#
# 'compile' took 0.073845 s
#
# Training model...
#
# 'train' took 16.376192 s
#
# 'compile' took 0.073856 s
#
# Training model...
#
# 'train' took 14.806389 s
#
# 'compile' took 0.073786 s
#
# Training model...
#
# 'train' took 14.609184 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#3/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#3/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#3/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#3/config
# [DOLPHINN] Weight: 1e-09 (0/5) (4/5)
# 'compile' took 0.001311 s
#
# Training model...
#
# 'train' took 13.760224 s
#
# 'compile' took 0.082441 s
#
# Training model...
#
# 'train' took 16.220420 s
#
# 'compile' took 0.079297 s
#
# Training model...
#
# 'train' took 26.448160 s
#
# 'compile' took 0.067808 s
#
# Training model...
#
# 'train' took 13.810825 s
#
# 'compile' took 0.070205 s
#
# Training model...
#
# 'train' took 15.283673 s
#
# 'compile' took 0.081634 s
#
# Training model...
#
# 'train' took 13.291725 s
#
# 'compile' took 0.068438 s
#
# Training model...
#
# 'train' took 15.808490 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#4/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#4/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#4/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_0_#4/config
# [DOLPHINN] Weight: 1e-08 (1/5) (0/5)
# 'compile' took 0.001811 s
#
# Training model...
#
# 'train' took 12.855274 s
#
# 'compile' took 0.077922 s
#
# Training model...
#
# 'train' took 15.510942 s
#
# 'compile' took 0.069968 s
#
# Training model...
#
# 'train' took 25.430727 s
#
# 'compile' took 0.071289 s
#
# Training model...
#
# 'train' took 14.242125 s
#
# 'compile' took 0.069731 s
#
# Training model...
#
# 'train' took 14.951170 s
#
# 'compile' took 0.071266 s
#
# Training model...
#
# 'train' took 13.502616 s
#
# 'compile' took 0.073804 s
#
# Training model...
#
# 'train' took 15.099982 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#0/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#0/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#0/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#0/config
# [DOLPHINN] Weight: 1e-08 (1/5) (1/5)
# 'compile' took 0.001310 s
#
# Training model...
#
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# 'train' took 11.027866 s
#
# 'compile' took 0.001369 s
#
# Training model...
#
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# 'train' took 9.873889 s
#
# 'compile' took 0.001594 s
#
# Training model...
#
# 'train' took 13.506844 s
#
# 'compile' took 0.078782 s
#
# Training model...
#
# WARNING:tensorflow:5 out of the last 16 calls to <function ObjectivePINN._compile_tensorflow.<locals>.outputs_losses_train at 0x000001E19B705000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 16 calls to <function ObjectivePINN._compile_tensorflow.<locals>.outputs_losses_test at 0x000001E19B704E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 'train' took 17.851721 s
#
# 'compile' took 0.091304 s
#
# Training model...
#
# 'train' took 27.573145 s
#
# 'compile' took 0.067330 s
#
# Training model...
#
# 'train' took 14.398545 s
#
# 'compile' took 0.069155 s
#
# Training model...
#
# 'train' took 16.451654 s
#
# 'compile' took 0.068146 s
#
# Training model...
#
# 'train' took 14.057703 s
#
# 'compile' took 0.069786 s
#
# Training model...
#
# 'train' took 16.347941 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#1/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#1/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#1/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#1/config
# [DOLPHINN] Weight: 1e-08 (1/5) (2/5)
# 'compile' took 0.001313 s
#
# Training model...
#
# 'train' took 13.695331 s
#
# 'compile' took 0.082769 s
#
# Training model...
#
# 'train' took 15.758451 s
#
# 'compile' took 0.074440 s
#
# Training model...
#
# 'train' took 26.520410 s
#
# 'compile' took 0.071840 s
#
# Training model...
#
# 'train' took 13.982401 s
#
# 'compile' took 0.071875 s
#
# Training model...
#
# 'train' took 14.622839 s
#
# 'compile' took 0.064995 s
#
# Training model...
#
# 'train' took 12.430550 s
#
# 'compile' took 0.065494 s
#
# Training model...
#
# 'train' took 14.194716 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#2/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#2/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#2/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#2/config
# [DOLPHINN] Weight: 1e-08 (1/5) (3/5)
# 'compile' took 0.001181 s
#
# Training model...
#
# 'train' took 12.265326 s
#
# 'compile' took 0.077641 s
#
# Training model...
#
# 'train' took 14.933343 s
#
# 'compile' took 0.066142 s
#
# Training model...
#
# 'train' took 24.072475 s
#
# 'compile' took 0.067764 s
#
# Training model...
#
# 'train' took 12.583125 s
#
# 'compile' took 0.066247 s
#
# Training model...
#
# 'train' took 14.434355 s
#
# 'compile' took 0.068718 s
#
# Training model...
#
# 'train' took 12.905102 s
#
# 'compile' took 0.077957 s
#
# Training model...
#
# 'train' took 14.625516 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#3/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#3/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#3/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#3/config
# [DOLPHINN] Weight: 1e-08 (1/5) (4/5)
# 'compile' took 0.001108 s
#
# Training model...
#
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# 'train' took 8.485225 s
#
# 'compile' took 0.001312 s
#
# Training model...
#
# 'train' took 13.116744 s
#
# 'compile' took 0.079788 s
#
# Training model...
#
# 'train' took 15.124395 s
#
# 'compile' took 0.069166 s
#
# Training model...
#
# 'train' took 25.774588 s
#
# 'compile' took 0.076522 s
#
# Training model...
#
# 'train' took 12.997629 s
#
# 'compile' took 0.068006 s
#
# Training model...
#
# 'train' took 15.258396 s
#
# 'compile' took 0.068086 s
#
# Training model...
#
# 'train' took 12.810252 s
#
# 'compile' took 0.067638 s
#
# Training model...
#
# 'train' took 15.659294 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#4/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#4/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#4/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_1_#4/config
# [DOLPHINN] Weight: 1e-07 (2/5) (0/5)
# 'compile' took 0.001099 s
#
# Training model...
#
# 'train' took 12.521783 s
#
# 'compile' took 0.076807 s
#
# Training model...
#
# 'train' took 14.600265 s
#
# 'compile' took 0.067132 s
#
# Training model...
#
# 'train' took 24.610139 s
#
# 'compile' took 0.067869 s
#
# Training model...
#
# 'train' took 13.837446 s
#
# 'compile' took 0.065988 s
#
# Training model...
#
# 'train' took 14.874382 s
#
# 'compile' took 0.068266 s
#
# Training model...
#
# 'train' took 13.601371 s
#
# 'compile' took 0.066516 s
#
# Training model...
#
# 'train' took 15.548895 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#0/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#0/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#0/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#0/config
# [DOLPHINN] Weight: 1e-07 (2/5) (1/5)
# 'compile' took 0.001204 s
#
# Training model...
#
# 'train' took 12.544418 s
#
# 'compile' took 0.077800 s
#
# Training model...
#
# 'train' took 16.618183 s
#
# 'compile' took 0.071248 s
#
# Training model...
#
# 'train' took 26.567552 s
#
# 'compile' took 0.069507 s
#
# Training model...
#
# 'train' took 13.611989 s
#
# 'compile' took 0.066550 s
#
# Training model...
#
# 'train' took 16.152400 s
#
# 'compile' took 0.071020 s
#
# Training model...
#
# 'train' took 13.594191 s
#
# 'compile' took 0.068742 s
#
# Training model...
#
# 'train' took 15.280305 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#1/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#1/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#1/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#1/config
# [DOLPHINN] Weight: 1e-07 (2/5) (2/5)
# 'compile' took 0.001083 s
#
# Training model...
#
# 'train' took 12.821545 s
#
# 'compile' took 0.079561 s
#
# Training model...
#
# 'train' took 15.012027 s
#
# 'compile' took 0.065078 s
#
# Training model...
#
# 'train' took 26.106832 s
#
# 'compile' took 0.066142 s
#
# Training model...
#
# 'train' took 13.566670 s
#
# 'compile' took 0.065172 s
#
# Training model...
#
# 'train' took 15.140854 s
#
# 'compile' took 0.068031 s
#
# Training model...
#
# 'train' took 13.444546 s
#
# 'compile' took 0.065951 s
#
# Training model...
#
# 'train' took 15.431808 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#2/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#2/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#2/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#2/config
# [DOLPHINN] Weight: 1e-07 (2/5) (3/5)
# 'compile' took 0.001209 s
#
# Training model...
#
# 'train' took 12.574519 s
#
# 'compile' took 0.075008 s
#
# Training model...
#
# 'train' took 15.130419 s
#
# 'compile' took 0.074997 s
#
# Training model...
#
# 'train' took 26.181499 s
#
# 'compile' took 0.068544 s
#
# Training model...
#
# 'train' took 13.967654 s
#
# 'compile' took 0.067794 s
#
# Training model...
#
# 'train' took 15.493018 s
#
# 'compile' took 0.067258 s
#
# Training model...
#
# 'train' took 13.270745 s
#
# 'compile' took 0.069386 s
#
# Training model...
#
# 'train' took 15.586915 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#3/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#3/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#3/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#3/config
# [DOLPHINN] Weight: 1e-07 (2/5) (4/5)
# 'compile' took 0.001174 s
#
# Training model...
#
# 'train' took 13.215131 s
#
# 'compile' took 0.001739 s
#
# Training model...
#
# 'train' took 13.253287 s
#
# 'compile' took 0.001535 s
#
# Training model...
#
# 'train' took 12.494310 s
#
# 'compile' took 0.078148 s
#
# Training model...
#
# 'train' took 17.159293 s
#
# 'compile' took 0.075582 s
#
# Training model...
#
# 'train' took 30.762957 s
#
# 'compile' took 0.078703 s
#
# Training model...
#
# 'train' took 15.857933 s
#
# 'compile' took 0.070224 s
#
# Training model...
#
# 'train' took 18.017945 s
#
# 'compile' took 0.075780 s
#
# Training model...
#
# 'train' took 16.356855 s
#
# 'compile' took 0.070926 s
#
# Training model...
#
# 'train' took 18.014753 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#4/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#4/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#4/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_2_#4/config
# [DOLPHINN] Weight: 1e-06 (3/5) (0/5)
# 'compile' took 0.001476 s
#
# Training model...
#
# 'train' took 14.654412 s
#
# 'compile' took 0.001524 s
#
# Training model...
#
# 'train' took 14.648104 s
#
# 'compile' took 0.080560 s
#
# Training model...
#
# 'train' took 18.437730 s
#
# 'compile' took 0.070223 s
#
# Training model...
#
# 'train' took 30.558148 s
#
# 'compile' took 0.071940 s
#
# Training model...
#
# 'train' took 16.268642 s
#
# 'compile' took 0.074661 s
#
# Training model...
#
# 'train' took 20.349304 s
#
# 'compile' took 0.081637 s
#
# Training model...
#
# 'train' took 16.141774 s
#
# 'compile' took 0.068186 s
#
# Training model...
#
# 'train' took 18.041878 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#0/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#0/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#0/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#0/config
# [DOLPHINN] Weight: 1e-06 (3/5) (1/5)
# 'compile' took 0.001421 s
#
# Training model...
#
# 'train' took 14.194335 s
#
# 'compile' took 0.001614 s
#
# Training model...
#
# 'train' took 15.543927 s
#
# 'compile' took 0.085025 s
#
# Training model...
#
# 'train' took 18.527737 s
#
# 'compile' took 0.073290 s
#
# Training model...
#
# 'train' took 31.312573 s
#
# 'compile' took 0.070364 s
#
# Training model...
#
# 'train' took 16.140588 s
#
# 'compile' took 0.072686 s
#
# Training model...
#
# 'train' took 18.548767 s
#
# 'compile' took 0.068023 s
#
# Training model...
#
# 'train' took 15.574410 s
#
# 'compile' took 0.072334 s
#
# Training model...
#
# 'train' took 17.937878 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#1/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#1/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#1/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#1/config
# [DOLPHINN] Weight: 1e-06 (3/5) (2/5)
# 'compile' took 0.001524 s
#
# Training model...
#
# 'train' took 15.260462 s
#
# 'compile' took 0.084148 s
#
# Training model...
#
# 'train' took 18.146616 s
#
# 'compile' took 0.072472 s
#
# Training model...
#
# 'train' took 30.669628 s
#
# 'compile' took 0.068423 s
#
# Training model...
#
# 'train' took 16.175675 s
#
# 'compile' took 0.070351 s
#
# Training model...
#
# 'train' took 17.987448 s
#
# 'compile' took 0.070829 s
#
# Training model...
#
# 'train' took 15.648384 s
#
# 'compile' took 0.070199 s
#
# Training model...
#
# 'train' took 17.887996 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#2/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#2/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#2/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#2/config
# [DOLPHINN] Weight: 1e-06 (3/5) (3/5)
# 'compile' took 0.001424 s
#
# Training model...
#
# 'train' took 14.907473 s
#
# 'compile' took 0.079892 s
#
# Training model...
#
# 'train' took 17.779805 s
#
# 'compile' took 0.080856 s
#
# Training model...
#
# 'train' took 30.846689 s
#
# 'compile' took 0.070027 s
#
# Training model...
#
# 'train' took 13.880970 s
#
# 'compile' took 0.064975 s
#
# Training model...
#
# 'train' took 16.102658 s
#
# 'compile' took 0.068991 s
#
# Training model...
#
# 'train' took 13.716198 s
#
# 'compile' took 0.067572 s
#
# Training model...
#
# 'train' took 15.876753 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#3/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#3/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#3/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#3/config
# [DOLPHINN] Weight: 1e-06 (3/5) (4/5)
# 'compile' took 0.001077 s
#
# Training model...
#
# 'train' took 12.627669 s
#
# 'compile' took 0.079496 s
#
# Training model...
#
# 'train' took 16.827790 s
#
# 'compile' took 0.065284 s
#
# Training model...
#
# 'train' took 27.131121 s
#
# 'compile' took 0.072684 s
#
# Training model...
#
# 'train' took 14.313185 s
#
# 'compile' took 0.068527 s
#
# Training model...
#
# 'train' took 16.800691 s
#
# 'compile' took 0.067640 s
#
# Training model...
#
# 'train' took 14.021415 s
#
# 'compile' took 0.068951 s
#
# Training model...
#
# 'train' took 17.307664 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#4/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#4/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#4/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_3_#4/config
# [DOLPHINN] Weight: 1e-05 (4/5) (0/5)
# 'compile' took 0.001171 s
#
# Training model...
#
# 'train' took 13.396880 s
#
# 'compile' took 0.078509 s
#
# Training model...
#
# 'train' took 16.475658 s
#
# 'compile' took 0.065427 s
#
# Training model...
#
# 'train' took 27.631264 s
#
# 'compile' took 0.065564 s
#
# Training model...
#
# 'train' took 13.903876 s
#
# 'compile' took 0.069173 s
#
# Training model...
#
# 'train' took 16.333495 s
#
# 'compile' took 0.067533 s
#
# Training model...
#
# 'train' took 14.359752 s
#
# 'compile' took 0.068089 s
#
# Training model...
#
# 'train' took 16.439577 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#0/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#0/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#0/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#0/config
# [DOLPHINN] Weight: 1e-05 (4/5) (1/5)
# 'compile' took 0.001228 s
#
# Training model...
#
# 'train' took 13.027299 s
#
# 'compile' took 0.075624 s
#
# Training model...
#
# 'train' took 16.192183 s
#
# 'compile' took 0.067739 s
#
# Training model...
#
# 'train' took 27.985882 s
#
# 'compile' took 0.070509 s
#
# Training model...
#
# 'train' took 13.909326 s
#
# 'compile' took 0.065306 s
#
# Training model...
#
# 'train' took 16.152476 s
#
# 'compile' took 0.074848 s
#
# Training model...
#
# 'train' took 13.721290 s
#
# 'compile' took 0.067945 s
#
# Training model...
#
# 'train' took 16.391837 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#1/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#1/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#1/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#1/config
# [DOLPHINN] Weight: 1e-05 (4/5) (2/5)
# 'compile' took 0.001231 s
#
# Training model...
#
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# [DOLPHINN] Error occured in metric: `y` must contain only finite values.
# 'train' took 8.416067 s
#
# 'compile' took 0.001233 s
#
# Training model...
#
# 'train' took 15.233303 s
#
# 'compile' took 0.077607 s
#
# Training model...
#
# 'train' took 19.306388 s
#
# 'compile' took 0.069414 s
#
# Training model...
#
# 'train' took 34.679306 s
#
# 'compile' took 0.068067 s
#
# Training model...
#
# 'train' took 16.494098 s
#
# 'compile' took 0.067082 s
#
# Training model...
#
# 'train' took 19.613315 s
#
# 'compile' took 0.066017 s
#
# Training model...
#
# 'train' took 16.705669 s
#
# 'compile' took 0.068731 s
#
# Training model...
#
# 'train' took 19.520146 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#2/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#2/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#2/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#2/config
# [DOLPHINN] Weight: 1e-05 (4/5) (3/5)
# 'compile' took 0.001391 s
#
# Training model...
#
# 'train' took 15.092746 s
#
# 'compile' took 0.077222 s
#
# Training model...
#
# 'train' took 20.254784 s
#
# 'compile' took 0.075006 s
#
# Training model...
#
# 'train' took 33.716176 s
#
# 'compile' took 0.066741 s
#
# Training model...
#
# 'train' took 16.700836 s
#
# 'compile' took 0.069404 s
#
# Training model...
#
# 'train' took 19.836179 s
#
# 'compile' took 0.068114 s
#
# Training model...
#
# 'train' took 16.892617 s
#
# 'compile' took 0.066680 s
#
# Training model...
#
# 'train' took 19.203383 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#3/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#3/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#3/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#3/config
# [DOLPHINN] Weight: 1e-05 (4/5) (4/5)
# 'compile' took 0.001240 s
#
# Training model...
#
# 'train' took 15.223134 s
#
# 'compile' took 0.078867 s
#
# Training model...
#
# 'train' took 19.715545 s
#
# 'compile' took 0.067542 s
#
# Training model...
#
# 'train' took 33.637167 s
#
# 'compile' took 0.069792 s
#
# Training model...
#
# 'train' took 16.731309 s
#
# 'compile' took 0.065744 s
#
# Training model...
#
# 'train' took 19.880677 s
#
# 'compile' took 0.066155 s
#
# Training model...
#
# 'train' took 16.354436 s
#
# 'compile' took 0.068038 s
#
# Training model...
#
# 'train' took 19.776356 s
#
# Saving loss history to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#4/loss.dat ...
# Saving training data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#4/train.dat ...
# Saving test data to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#4/test.dat ...
# [DOLPHINN] Saving config file to ../data/Optimisation/LVLHtm_fuel/mars_1_revolv_weights_grid/weight_4_#4/config

# %%
#animation = StoreAnimationData("../Data/Optimisation/LVLH_fuel/case6/")

problem = DOLPHINN(data,
                    "TwoBodyProblemRadialThetaNonDimensionalControl_mass",
                    output_transform = "InitialFinalStateLayer_RadialTheta_tanh_mass",
                    objective = "OptimalFuel", 
                    metrics = [FinalDr, FinalDv, FinalDm, Fuel])
mweigth = 1e-5
oweigth = 1e-8
tweigth = 1

restarter = Restarter([(1e-2, 3000)], loss_weigths = [1, tweigth, 1, 1, mweigth, oweigth])
schedule = Scheduler([(1e-3, 5000), (1e-4, 10000)],
                     loss_weigths= [1, tweigth, 1, 1, mweigth, oweigth])
problem.train([restarter, schedule])
# Out:
# [DOLPHINN] Using time-dependent random seed: 20230718133146
#
# [DOLPHINN] Training with procedure: Restarter
#
# [RESTARTER] Initialisation attempt: 1
# Compiling model...
# 'compile' took 0.002264 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [2.55e+00, 3.94e+02, 8.89e+01, 3.04e+00, 2.67e-02, 3.34e-06]    [1.32e+00, 2.04e+02, 8.78e+01, 1.59e+00, 1.44e-02, 3.34e-06]    [3.25e+01, 2.68e+00, 2.87e+02, 3.34e+02]
# 1000      [1.10e-03, 1.92e-02, 1.78e-04, 5.26e-04, 1.88e-04, 7.64e-07]    [1.42e-03, 1.31e-02, 1.58e-04, 3.53e-04, 1.24e-04, 7.64e-07]    [8.15e-01, 2.03e-01, 4.55e+01, 7.64e+01]
# 2000      [3.10e-04, 4.34e-03, 3.26e-05, 1.60e-04, 3.75e-05, 3.02e-07]    [3.69e-04, 4.15e-03, 3.63e-05, 1.05e-04, 2.71e-05, 3.02e-07]    [2.30e+00, 1.74e+00, 1.23e+00, 3.02e+01]
# 3000      [8.11e-05, 1.89e-02, 1.54e-04, 1.56e-04, 1.49e-05, 2.24e-07]    [8.34e-05, 1.07e-02, 9.02e-05, 1.14e-04, 1.18e-05, 2.24e-07]    [2.59e+00, 1.78e+00, 1.08e+00, 2.24e+01]
#
# Best model at step 2000:
#   train loss: 4.88e-03
#   test loss: 4.69e-03
#   test metric: [2.30e+00, 1.74e+00, 1.23e+00, 3.02e+01]
#
# 'train' took 16.045202 s
#
#
# [DOLPHINN] Training with procedure: Scheduler
#
# Compiling model...
# 'compile' took 0.081730 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 3000      [8.11e-05, 1.89e-02, 1.54e-04, 1.56e-04, 1.49e-05, 2.24e-07]    [8.34e-05, 1.07e-02, 9.02e-05, 1.14e-04, 1.18e-05, 2.24e-07]    [2.59e+00, 1.78e+00, 1.08e+00, 2.24e+01]
# 4000      [1.71e-05, 3.00e-04, 5.37e-06, 1.29e-05, 4.27e-06, 1.62e-07]    [2.00e-05, 2.94e-04, 5.97e-06, 1.27e-05, 4.36e-06, 1.62e-07]    [1.95e+00, 1.22e+00, 1.34e+01, 1.62e+01]
# 5000      [4.79e-06, 3.92e-04, 2.12e-06, 4.62e-06, 4.43e-06, 1.89e-07]    [5.68e-06, 3.13e-04, 2.23e-06, 4.62e-06, 4.47e-06, 1.89e-07]    [1.49e+00, 8.46e-01, 1.45e+01, 1.89e+01]
# 6000      [3.06e-06, 2.10e-04, 2.78e-06, 3.17e-06, 8.74e-07, 1.99e-07]    [3.66e-06, 2.00e-04, 3.02e-06, 3.16e-06, 7.54e-07, 1.99e-07]    [6.56e-01, 3.57e-01, 2.56e+00, 1.99e+01]
# 7000      [2.36e-06, 1.84e-04, 3.11e-06, 3.34e-06, 5.20e-07, 1.98e-07]    [2.76e-06, 1.78e-04, 3.41e-06, 3.23e-06, 4.85e-07, 1.98e-07]    [7.41e-01, 4.05e-01, 1.93e+00, 1.98e+01]
# 8000      [2.09e-06, 1.79e-04, 3.02e-06, 3.09e-06, 3.02e-07, 1.98e-07]    [2.29e-06, 1.66e-04, 3.34e-06, 3.07e-06, 2.70e-07, 1.98e-07]    [6.66e-01, 3.64e-01, 1.20e+00, 1.98e+01]
#
# Best model at step 8000:
#   train loss: 1.88e-04
#   test loss: 1.76e-04
#   test metric: [6.66e-01, 3.64e-01, 1.20e+00, 1.98e+01]
#
# 'train' took 21.223843 s
#
# Compiling model...
# 'compile' took 0.067113 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 8000      [2.09e-06, 1.79e-04, 3.02e-06, 3.09e-06, 3.02e-07, 1.98e-07]    [2.29e-06, 1.66e-04, 3.34e-06, 3.07e-06, 2.70e-07, 1.98e-07]    [6.66e-01, 3.64e-01, 1.20e+00, 1.98e+01]
# 9000      [2.00e-06, 1.46e-04, 2.70e-06, 2.96e-06, 2.92e-07, 2.00e-07]    [2.19e-06, 1.42e-04, 3.04e-06, 3.05e-06, 2.65e-07, 2.00e-07]    [6.33e-01, 3.48e-01, 1.19e+00, 2.00e+01]
# 10000     [2.00e-06, 1.30e-04, 2.71e-06, 2.90e-06, 2.99e-07, 2.01e-07]    [2.16e-06, 1.25e-04, 3.06e-06, 3.01e-06, 2.74e-07, 2.01e-07]    [5.71e-01, 3.14e-01, 1.21e+00, 2.01e+01]
# 11000     [1.95e-06, 1.23e-04, 2.53e-06, 2.85e-06, 2.82e-07, 2.02e-07]    [2.07e-06, 1.18e-04, 2.87e-06, 2.94e-06, 2.55e-07, 2.02e-07]    [5.06e-01, 2.78e-01, 1.11e+00, 2.02e+01]
# 12000     [1.85e-06, 1.18e-04, 2.22e-06, 2.72e-06, 2.50e-07, 2.03e-07]    [1.94e-06, 1.13e-04, 2.53e-06, 2.80e-06, 2.23e-07, 2.03e-07]    [4.45e-01, 2.45e-01, 9.62e-01, 2.03e+01]
# 13000     [1.84e-06, 1.29e-04, 1.89e-06, 2.52e-06, 2.15e-07, 2.03e-07]    [1.91e-06, 1.16e-04, 2.16e-06, 2.58e-06, 1.89e-07, 2.03e-07]    [3.95e-01, 2.18e-01, 8.08e-01, 2.03e+01]
# 14000     [1.67e-06, 1.14e-04, 1.61e-06, 2.32e-06, 1.83e-07, 2.04e-07]    [1.70e-06, 1.08e-04, 1.87e-06, 2.37e-06, 1.60e-07, 2.04e-07]    [3.45e-01, 1.91e-01, 6.74e-01, 2.04e+01]
# 15000     [1.60e-06, 1.12e-04, 1.37e-06, 2.11e-06, 1.55e-07, 2.04e-07]    [1.61e-06, 1.07e-04, 1.60e-06, 2.14e-06, 1.37e-07, 2.04e-07]    [3.05e-01, 1.69e-01, 5.54e-01, 2.04e+01]
# 16000     [1.56e-06, 1.15e-04, 1.16e-06, 1.91e-06, 1.33e-07, 2.04e-07]    [1.57e-06, 1.07e-04, 1.35e-06, 1.92e-06, 1.18e-07, 2.04e-07]    [2.72e-01, 1.51e-01, 4.58e-01, 2.04e+01]
# 17000     [1.48e-06, 1.11e-04, 9.99e-07, 1.73e-06, 1.15e-07, 2.05e-07]    [1.47e-06, 1.05e-04, 1.17e-06, 1.73e-06, 1.04e-07, 2.05e-07]    [2.38e-01, 1.32e-01, 3.82e-01, 2.05e+01]
# 18000     [1.43e-06, 1.10e-04, 8.67e-07, 1.57e-06, 1.01e-07, 2.05e-07]    [1.41e-06, 1.04e-04, 1.01e-06, 1.56e-06, 9.23e-08, 2.05e-07]    [2.09e-01, 1.17e-01, 3.22e-01, 2.05e+01]
#
# Best model at step 18000:
#   train loss: 1.14e-04
#   test loss: 1.08e-04
#   test metric: [2.09e-01, 1.17e-01, 3.22e-01, 2.05e+01]
#
# 'train' took 36.983175 s
#
# [DOLPHINN] This training ['Restarter', 'Scheduler'] took 74.41 s
# [DOLPHINN] The entire training so far took: 74.41 s

# %%
schedule = Scheduler([(1e-5, 10000)],
                     loss_weigths= [1, tweigth, 1, 1, mweigth, oweigth])
problem.train([schedule])
# Out:
# [DOLPHINN] Training with procedure: Scheduler
#
# Compiling model...
# 'compile' took 0.072317 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 38000     [9.58e-07, 1.05e-04, 2.36e-07, 5.41e-07, 3.74e-08, 2.05e-07]    [9.10e-07, 9.90e-05, 2.24e-07, 5.22e-07, 3.73e-08, 2.05e-07]    [5.39e-02, 2.96e-02, 9.09e-02, 2.05e+01]
# 39000     [9.49e-07, 1.05e-04, 2.34e-07, 5.38e-07, 3.74e-08, 2.05e-07]    [9.00e-07, 9.90e-05, 2.22e-07, 5.18e-07, 3.73e-08, 2.05e-07]    [5.29e-02, 2.90e-02, 8.99e-02, 2.05e+01]
# 40000     [9.30e-07, 1.05e-04, 2.29e-07, 5.29e-07, 3.73e-08, 2.05e-07]    [8.85e-07, 9.89e-05, 2.16e-07, 5.10e-07, 3.71e-08, 2.05e-07]    [4.87e-02, 2.68e-02, 8.59e-02, 2.05e+01]
# 41000     [9.08e-07, 1.05e-04, 2.26e-07, 5.21e-07, 3.72e-08, 2.06e-07]    [8.61e-07, 9.86e-05, 2.13e-07, 5.02e-07, 3.70e-08, 2.06e-07]    [4.41e-02, 2.43e-02, 8.23e-02, 2.06e+01]
# 42000     [8.87e-07, 1.05e-04, 2.23e-07, 5.14e-07, 3.71e-08, 2.06e-07]    [8.40e-07, 9.83e-05, 2.09e-07, 4.95e-07, 3.69e-08, 2.06e-07]    [4.04e-02, 2.23e-02, 7.80e-02, 2.06e+01]
# 43000     [8.66e-07, 1.05e-04, 2.19e-07, 5.07e-07, 3.70e-08, 2.06e-07]    [8.13e-07, 9.92e-05, 2.08e-07, 4.88e-07, 3.67e-08, 2.06e-07]    [3.62e-02, 2.00e-02, 7.64e-02, 2.06e+01]
# 44000     [8.45e-07, 1.05e-04, 2.19e-07, 5.03e-07, 3.68e-08, 2.06e-07]    [7.90e-07, 9.88e-05, 2.07e-07, 4.83e-07, 3.65e-08, 2.06e-07]    [3.35e-02, 1.85e-02, 7.28e-02, 2.06e+01]
# 45000     [8.24e-07, 1.04e-04, 2.15e-07, 4.92e-07, 3.67e-08, 2.06e-07]    [7.78e-07, 9.79e-05, 2.02e-07, 4.74e-07, 3.63e-08, 2.06e-07]    [3.21e-02, 1.77e-02, 6.81e-02, 2.06e+01]
# 46000     [8.02e-07, 1.04e-04, 2.13e-07, 4.86e-07, 3.65e-08, 2.06e-07]    [7.57e-07, 9.77e-05, 2.00e-07, 4.68e-07, 3.62e-08, 2.06e-07]    [3.01e-02, 1.67e-02, 6.50e-02, 2.06e+01]
# 47000     [7.82e-07, 1.04e-04, 2.11e-07, 4.80e-07, 3.63e-08, 2.06e-07]    [7.39e-07, 9.75e-05, 1.98e-07, 4.62e-07, 3.60e-08, 2.06e-07]    [2.86e-02, 1.59e-02, 6.20e-02, 2.06e+01]
# 48000     [7.61e-07, 1.03e-04, 2.10e-07, 4.75e-07, 3.62e-08, 2.06e-07]    [7.18e-07, 9.74e-05, 1.97e-07, 4.57e-07, 3.58e-08, 2.06e-07]    [2.71e-02, 1.50e-02, 5.97e-02, 2.06e+01]
#
# Best model at step 48000:
#   train loss: 1.05e-04
#   test loss: 9.91e-05
#   test metric: [2.71e-02, 1.50e-02, 5.97e-02, 2.06e+01]
#
# 'train' took 37.347705 s
#
# [DOLPHINN] This training ['Scheduler'] took 37.42 s
# [DOLPHINN] The entire training so far took: 183.84 s

# %%
problem.print_config()
# Out:
#  ==================== Config Content ====================
#
# ----------Functions----------
# dynamics                       TwoBodyProblemRadialThetaNonDimensionalControl_mass
# input_transform                NoneType
# output_transform               InitialFinalStateLayer_RadialTheta_tanh_mass
# objective                      OptimalFuel
#
# ----------Problem----------
# initial_state                  [1.0, 0.0, 0.0, 1.0]
# final_state                    [1.5, 18.84955592153876, 0.0, 0.816496580927726]
# mu                             1.32712440042e+20
# m                              100
# a                              10
# umax                           0.1
# isp                            2500
# length_scale                   150000000000.0
# time_scale                     5042908.305393074
# t0                             0.0
# tfinal                         26.34305524140272
#
# ----------Network----------
# architecture                   [1, 20, 20, 20, 20, 7]
# activation                     tanh
# sampler                        perturbed_uniform_tf
# N_train                        200
# N_boundary                     2
# N_test                         200
# seed                           20230718133146
#
# ----------Metrics----------
# metric_1                       FinalDr
# metric_2                       FinalDv
# metric_3                       FinalDm
# metric_4                       Fuel
#
# ----------Training----------
# train_0                        Restarter
#     loss_threshold             10
#     loss_weigths               [1, 1, 1, 1, 1e-05, 1e-08]
#     max_attempts               50
#     schedule                   [(0.01, 3000)]
#
# train_1                        Scheduler
#     loss_weigths               [1, 1, 1, 1, 1e-05, 1e-08]
#     schedule                   [(0.001, 5000), (0.0001, 10000)]
#
# train_time                     183.8437581062317
# train_2                        Scheduler
#     loss_weigths               [1, 1, 1, 1, 1e-05, 1e-08]
#     schedule                   [(0.0001, 10000)]
#
# train_3                        Scheduler
#     loss_weigths               [1, 1, 1, 1, 1e-05, 1e-08]
#     schedule                   [(0.0001, 10000)]
#
# train_4                        Scheduler
#     loss_weigths               [1, 1, 1, 1, 1e-05, 1e-08]
#     schedule                   [(1e-05, 10000)]
#
#
# =======================================================

# %%
problem.verify()
plotting.plot_loss(problem, objective_zoom=True)  
plotting.plot_transfer(problem, bench = False, thrust_scale = 0.01, r_target = 1.5, N_arrows = 80, lim = 2.3)
plotting.compare(problem, 'NDcartesian', log = False)
plotting.plot_coordinates(problem, "radial")
plotting.compare_mass(problem)
plotting.plot_metrics(problem)
# Out:
# [DOLPHINN] Setting up the TUDAT simulation
# [DOLPHINN] Guidance is internal!
# [DOLPHINN] Start Integrating
# [DOLPHINN] Finished integrating in 0.1275 s

# %%
problem.store("../Data/Optimisation/LVLHtm_fuel/case6/", overwrite = False)
# Out:
# Saving loss history to ../Data/Optimisation/LVLHtm_fuel/case6/loss.dat ...
# Saving training data to ../Data/Optimisation/LVLHtm_fuel/case6/train.dat ...
# Saving test data to ../Data/Optimisation/LVLHtm_fuel/case6/test.dat ...
# [DOLPHINN] Saving config file to ../Data/Optimisation/LVLHtm_fuel/case6/config
